# %% [markdown]
# <a href="https://colab.research.google.com/github/SadhanaGhodke/DSBDA/blob/main/A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

df = pd.read_csv ("/content/iris_synthetic_data.csv")
df
# Out:
#       sepal length  sepal width  petal length  petal width           label
# 0              5.2          3.8           1.5          0.3     Iris-setosa
# 1              5.3          4.1           1.5          0.1     Iris-setosa
# 2              4.8          3.1           1.5          0.2     Iris-setosa
# 3              5.2          3.7           1.5          0.2     Iris-setosa
# 4              4.9          3.0           1.5          0.3     Iris-setosa
# ...            ...          ...           ...          ...             ...
# 2995           7.2          3.6           6.0          2.5  Iris-virginica
# 2996           7.3          3.0           6.2          2.1  Iris-virginica
# 2997           6.9          3.2           5.7          2.3  Iris-virginica
# 2998           7.5          2.8           6.0          2.0  Iris-virginica
# 2999           6.7          3.0           5.3          2.3  Iris-virginica
#
# [3000 rows x 5 columns]

# %%
df.isnull()
# Out:
#       sepal length  sepal width  petal length  petal width  label
# 0            False        False         False        False  False
# 1            False        False         False        False  False
# 2            False        False         False        False  False
# 3            False        False         False        False  False
# 4            False        False         False        False  False
# ...            ...          ...           ...          ...    ...
# 2995         False        False         False        False  False
# 2996         False        False         False        False  False
# 2997         False        False         False        False  False
# 2998         False        False         False        False  False
# 2999         False        False         False        False  False
#
# [3000 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# label           0
# dtype: int64

# %%
df.isnull().any()
# Out:
# sepal length    False
# sepal width     False
# petal length    False
# petal width     False
# label           False
# dtype: bool

# %%
df.loc [0, "sepal length"] = np.nan

# %%
df
# Out:
#       sepal length  sepal width  petal length  petal width           label
# 0              NaN          3.8           1.5          0.3     Iris-setosa
# 1              5.3          4.1           1.5          0.1     Iris-setosa
# 2              4.8          3.1           1.5          0.2     Iris-setosa
# 3              5.2          3.7           1.5          0.2     Iris-setosa
# 4              4.9          3.0           1.5          0.3     Iris-setosa
# ...            ...          ...           ...          ...             ...
# 2995           7.2          3.6           6.0          2.5  Iris-virginica
# 2996           7.3          3.0           6.2          2.1  Iris-virginica
# 2997           6.9          3.2           5.7          2.3  Iris-virginica
# 2998           7.5          2.8           6.0          2.0  Iris-virginica
# 2999           6.7          3.0           5.3          2.3  Iris-virginica
#
# [3000 rows x 5 columns]

# %%
print ("\n",df.isnull().sum())
print ("\n", df.isnull().sum().sum())
print ("\n", df.isnull().sum(axis = 1))
# Out:
#  sepal length    1
# sepal width     0
# petal length    0
# petal width     0
# label           0
# dtype: int64
#
#  1
#
#  0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2995    0
# 2996    0
# 2997    0
# 2998    0
# 2999    0
# Length: 3000, dtype: int64

# %%
df.dtypes
# Out:
# sepal length    float64
# sepal width     float64
# petal length    float64
# petal width     float64
# label            object
# dtype: object

# %%
print (df.head())
print ("\n",df.tail())
print ("\n",df.index)
print ("\n",df.columns)
print ('\n', df['label'])
# Out:
#    sepal length  sepal width  petal length  petal width        label
# 0           NaN          3.8           1.5          0.3  Iris-setosa
# 1           5.3          4.1           1.5          0.1  Iris-setosa
# 2           4.8          3.1           1.5          0.2  Iris-setosa
# 3           5.2          3.7           1.5          0.2  Iris-setosa
# 4           4.9          3.0           1.5          0.3  Iris-setosa
#
#        sepal length  sepal width  petal length  petal width           label
# 2995           7.2          3.6           6.0          2.5  Iris-virginica
# 2996           7.3          3.0           6.2          2.1  Iris-virginica
# 2997           6.9          3.2           5.7          2.3  Iris-virginica
# 2998           7.5          2.8           6.0          2.0  Iris-virginica
# 2999           6.7          3.0           5.3          2.3  Iris-virginica
#
#  RangeIndex(start=0, stop=3000, step=1)
#
# ...

# %%
print ('\n', df.iloc[5])
print ('\n', df.loc [0:3])
print ('\n',df.loc[:, ["sepal length","label"]])
print ('\n', df.iloc[:6, :])
print ('\n', df.iloc[:, :6])
print ('\n',df.iloc[:7, :5])
# Out:
#  sepal length            5.1
# sepal width             3.7
# petal length            1.5
# petal width             0.4
# label           Iris-setosa
# Name: 5, dtype: object
#
#     sepal length  sepal width  petal length  petal width        label
# 0           NaN          3.8           1.5          0.3  Iris-setosa
# 1           5.3          4.1           1.5          0.1  Iris-setosa
# 2           4.8          3.1           1.5          0.2  Iris-setosa
# 3           5.2          3.7           1.5          0.2  Iris-setosa
#
#        sepal length           label
# 0              NaN     Iris-setosa
# 1              5.3     Iris-setosa
# 2              4.8     Iris-setosa
# 3              5.2     Iris-setosa
# 4              4.9     Iris-setosa
# ...            ...             ...
# 2995           7.2  Iris-virginica
# 2996           7.3  Iris-virginica
# 2997           6.9  Iris-virginica
# 2998           7.5  Iris-virginica
# 2999           6.7  Iris-virginica
#
# ...

# %%
df["petal length"] =df["petal length"].astype("int")
df.dtypes
# Out:
# sepal length    float64
# sepal width     float64
# petal length      int64
# petal width     float64
# label            object
# dtype: object

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count   2999.000000  3000.000000   3000.000000  3000.000000
# mean       5.865488     3.051833      3.296000     1.191000
# std        0.805116     0.412472      1.771091     0.758022
# min        4.300000     2.000000      0.000000     0.100000
# 25%        5.100000     2.800000      1.000000     0.300000
# 50%        5.800000     3.000000      4.000000     1.300000
# 75%        6.400000     3.300000      5.000000     1.800000
# max        7.900000     4.400000      6.000000     2.500000

# %%
df.shape
# Out:
# (3000, 5)

# %%
df['label'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler

features = df.iloc[:, :-1]  # All columns except the last one (numerical features)
labels = df.iloc[:, -1]     # Last column (categorical labels)

scaler = MinMaxScaler()
features_scaled = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)

df_scaled = pd.concat([features_scaled, labels], axis=1)

print(df_scaled.head())
# Out:
#    sepal length  sepal width  petal length  petal width        label
# 0           NaN     0.750000      0.166667     0.083333  Iris-setosa
# 1      0.277778     0.875000      0.166667     0.000000  Iris-setosa
# 2      0.138889     0.458333      0.166667     0.041667  Iris-setosa
# 3      0.250000     0.708333      0.166667     0.041667  Iris-setosa
# 4      0.166667     0.416667      0.166667     0.083333  Iris-setosa

# %%
from sklearn import preprocessing
label2 = preprocessing.LabelEncoder()
df['en_label'] = label2.fit_transform(df['label'])
df['en_label'].unique()
# Out:
# array([0, 1, 2])

# %%
df['dec_label'] = label2.inverse_transform(df['en_label'])
df['dec_label'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df
# Out:
#       sepal length  sepal width  petal length  petal width           label  \
# 0              5.2          3.8           1.5          0.3     Iris-setosa
# 1              5.3          4.1           1.5          0.1     Iris-setosa
# 2              4.8          3.1           1.5          0.2     Iris-setosa
# 3              5.2          3.7           1.5          0.2     Iris-setosa
# 4              4.9          3.0           1.5          0.3     Iris-setosa
# ...            ...          ...           ...          ...             ...
# 2995           7.2          3.6           6.0          2.5  Iris-virginica
# 2996           7.3          3.0           6.2          2.1  Iris-virginica
# 2997           6.9          3.2           5.7          2.3  Iris-virginica
# 2998           7.5          2.8           6.0          2.0  Iris-virginica
# 2999           6.7          3.0           5.3          2.3  Iris-virginica
#
#       en_label       dec_label
# 0            0     Iris-setosa
# ...
